# %% [markdown]
# ---
# title: "First Notebook Test"
# date: "2026-01-10"
# description: "My first quarto wiki notebook demonstrating basic Python operations"
# ---
#
# # This is a test file
#
# First quarto wiki notebook

# %%
a = 1
b = 2

# %%
print(f"The sum of a and b is: {a + b}")
# Out:
# The sum of a and b is: 3
